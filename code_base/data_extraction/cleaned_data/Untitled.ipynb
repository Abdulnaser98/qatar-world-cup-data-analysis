# %%
import pandas as pd 
aljazerra_data = pd.read_csv("aljazerra_cleaned_data.csv", sep= ",")

# %%
aljazerra_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                      date  \
# 0           0             0  Published On 19 Dec 2022
# 1           1             1  Published On 19 Dec 2022
# 2           2             2  Published On 19 Dec 2022
# 3           3             3  Published On 19 Dec 2022
# 4           4             4  Published On 18 Dec 2022
#
#                                        title  \
# 0  pure joy argentina erupts celebration win
# 1   lionel messi breakdown career highlights
# 2                        bisht messi wearing
# 3        predictions many games ai get right
# 4     tears relief joy messi lifts argentina
#
#                                           head_titel  \
# 0  An explosion of hope and joy engulfs the natio...
# 1  After inspiring Argentina to a historic World ...
# 2  The emir of Qatar put a bisht on Argentina cap...
# 3  In total, Kashef, our AI robot, had a 67 perce...
# 4  Waves of euphoria sweep through Lusail Stadium...
#
# ...

# %%
aljazerra_data = aljazerra_data.sort_values('title_main_content_negaitve_mean', ascending=False)
aljazerra_data.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1                      date  \
# 669         669           669  Published On 28 Sep 2022
# 173         173           173   Published On 7 Dec 2022
# 715         715           715  Published On 30 Mar 2022
# 712         712           712  Published On 31 Mar 2022
# 389         389           389  Published On 25 Nov 2022
#
#                                                  title  \
# 669  brazil richarlison demands action banana throw...
# 173          samuel eto apologises attacking man match
# 715           nigerian riot qualification defeat ghana
# 712       algerian fa files complaint qualifier defeat
# 389                neymar miss rest group stage injury
#
#                                             head_titel  \
# 669  Brazilian footballer Richarlison subjected to ...
# 173  Cameroon Football Federation President was fil...
# 715  Ghana became the first African nation to quali...
# 712  Algerian football federation demands FIFA orde...
# ...
